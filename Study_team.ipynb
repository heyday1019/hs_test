# %%
import pandas as pd

afl_finalists = pd.read_csv('https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/afl_finalists.csv')
afl_margins = pd.read_csv('https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/afl_margins.csv')

# %%
print(afl_finalists)
# Out:
#         afl.finalists
# 0            Hawthorn
# 1           Melbourne
# 2             Carlton
# 3           Melbourne
# 4            Hawthorn
# ..                ...
# 395            Sydney
# 396           Geelong
# 397  Western Bulldogs
# 398          St Kilda
# 399          St Kilda
#
# [400 rows x 1 columns]

# %%
afl_finalists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   afl.finalists  400 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
df = pd.DataFrame(afl_finalists)
df.head()
# Out:
#   afl.finalists
# 0      Hawthorn
# 1     Melbourne
# 2       Carlton
# 3     Melbourne
# 4      Hawthorn

# %%
import seaborn as sns
ax = sns.histplot(afl_margins)
ax.set(xlabel = "Winning Margin", ylabel = "frequency")
sns.despine()

# %%
df2 = pd.DataFrame(afl_margins)
df2
# Out:
#      afl.margins
# 0             56
# 1             31
# 2             56
# 3              8
# 4             32
# ..           ...
# 171           28
# 172           38
# 173           29
# 174           10
# 175           10
#
# [176 rows x 1 columns]
